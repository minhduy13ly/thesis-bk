# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd "/content/gdrive/MyDrive/THESIS RESOURCES/Diversity Demo"
# Out:
# /content/gdrive/MyDrive/THESIS RESOURCES/Diversity Demo

# %%
! python demo.py
